# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
vendas = pd.read_csv('vendas.csv')
df_clientes = pd.read_csv('clientes.csv')   
df_produtos = pd.read_csv('produtos.csv')
df_campanhas = pd.read_csv('campanhas.csv')
df_avaliacoes = pd.read_csv('avaliacoes.csv')
df_atendimentos = pd.read_csv('atendimentos.csv')
vendas1 = pd.read_csv('venda 1.csv')
vendas2 = pd.read_csv('venda 2.csv' )
vendas3 = pd.read_csv('venda 3.csv' )
sem_marca = pd.read_csv('produtos_sem_marca_corrigidos.csv')
novo_produto = pd.read_csv('Produto adicional.csv', sep=';', )

# %%
produtos_completo = pd.concat([df_produtos, novo_produto], ignore_index=True)
produtos_completo.drop_duplicates(subset='Nome_Produto', inplace=True)
produtos_completo
# Out:
#     ID_Produto                   Nome_Produto         Categoria    Preco  \
# 0            1           Máquina de Lavar 8kg  Eletrodomésticos  1632.61
# 1            2  Smartphone Samsung Galaxy S21  Eletrodomésticos  3306.28
# 2            3         Notebook Dell Inspiron  Eletrodomésticos  1236.89
# 3            4                      TV LG 50"       Eletrônicos   170.47
# 4            5  Geladeira Brastemp Frost Free  Eletrodomésticos  3845.33
# ..         ...                            ...               ...      ...
# 95          96              Smartwatch Huawei       Informática   428.38
# 96          97       Máquina de Costura Elgin            Móveis  4879.18
# 97          98             Ventilador Mondial            Móveis  4103.17
# 98          99             Cooktop Electrolux            Móveis  4277.48
# 99         100                         Mouse        Informática      NaN
#
#          Marca
# 0          NaN
# 1      Samsung
# 2         Dell
# 3           LG
# 4     Brastemp
# ..         ...
# 95      Huawei
# 96          LG
# 97     Mondial
# 98  Electrolux
# 99       Inova
#
# [100 rows x 5 columns]

# %%
produtos_completo.set_index('ID_Produto', inplace=True)
sem_marca.set_index('ID_Produto', inplace=True)

tabela_join = produtos_completo.join(sem_marca, how='left', rsuffix='_corrigido')
tabela_join['Marca'] = tabela_join['Marca'].fillna(tabela_join['Marca_corrigido'])
tabela_join.drop(columns=['Marca_corrigido'], inplace=True)
produtos_completo = tabela_join.reset_index()
produtos_completo
# Out:
#     ID_Produto                   Nome_Produto         Categoria    Preco  \
# 0            1           Máquina de Lavar 8kg  Eletrodomésticos  1632.61
# 1            2  Smartphone Samsung Galaxy S21  Eletrodomésticos  3306.28
# 2            3         Notebook Dell Inspiron  Eletrodomésticos  1236.89
# 3            4                      TV LG 50"       Eletrônicos   170.47
# 4            5  Geladeira Brastemp Frost Free  Eletrodomésticos  3845.33
# ..         ...                            ...               ...      ...
# 95          96              Smartwatch Huawei       Informática   428.38
# 96          97       Máquina de Costura Elgin            Móveis  4879.18
# 97          98             Ventilador Mondial            Móveis  4103.17
# 98          99             Cooktop Electrolux            Móveis  4277.48
# 99         100                         Mouse        Informática      NaN
#
#          Marca
# 0     Brastemp
# 1      Samsung
# 2         Dell
# 3           LG
# 4     Brastemp
# ..         ...
# 95      Huawei
# 96          LG
# 97     Mondial
# 98  Electrolux
# 99       Inova
#
# [100 rows x 5 columns]

# %%
produtos_completo.to_csv('produtos_completo.csv', index=False)

# %%
df_vendas = pd.concat([vendas, vendas1, vendas2, vendas3], ignore_index=True)

# %%
df_clientes.columns = df_clientes.columns.str.strip().str.lower()
df_vendas.columns = df_vendas.columns.str.strip().str.lower()
produtos_completo.columns = produtos_completo.columns.str.strip().str.lower()

# %%
clientes_vendas = pd.merge(df_vendas, df_clientes, on="id_cliente", how="left")
tabela_final = pd.merge(clientes_vendas, produtos_completo, on="id_produto", how="left")

# %%
tabela_final['data'] = tabela_final['data'].astype(str).str.replace(' 00:00:00', '', regex=False)

# %%
tabela_final
# Out:
#        id_venda  id_cliente  id_produto        data  quantidade        canal  \
# 0             1         350          45  2022-09-23           4       Online
# 1             2         925          68  2024-02-09           1  Loja Física
# 2             3         915          75  2022-09-11           4       Online
# 3             4         494          47  2024-05-10           4  Loja Física
# 4             5         523          79  2023-10-15           4  Loja Física
# ...         ...         ...         ...         ...         ...          ...
# 23995     23195          99          68  2024-11-06           2       Online
# 23996     23196         225          90  2024-10-14           2  Loja Física
# 23997     23197         974          15  2024-12-29           4  Loja Física
# 23998     23198         269          44  2025-06-13           3  Loja Física
# 23999     23199          54          23  2024-12-02           2       Online
#
#        valor_total               nome  idade sexo          cidade estado  \
# 0          5795.64  Davi Luiz Peixoto     39    F  Rio de Janeiro     MG
# 1          4614.41       Murilo Cunha     28    M    Porto Alegre     PR
# 2          2057.48       Jade Freitas     30    M    Porto Alegre     RJ
# 3         12864.44  Kevin Casa Grande     51    F        Curitiba     PR
# 4         13317.28     Asafe Mendonça     29    F    Porto Alegre     SP
# ...            ...                ...    ...  ...             ...    ...
# 23995    922882.00  Ana Lívia Pereira     46    M       São Paulo     RS
# 23996    653663.00   Ana Clara Cirino     54    F  Belo Horizonte     RJ
# 23997   1256521.00     Yasmin Pimenta     66    F       São Paulo     PR
# 23998    983499.00      Ester Azevedo     37    M  Belo Horizonte     PR
# 23999    929618.00  Davi Lucas Araújo     43    M  Belo Horizonte     MG
#
#       canal_aquisicao                 nome_produto         categoria    preco  \
# 0         Loja Física  Fritadeira Airfryer Mondial            Móveis  1448.91
# 1              Online         Monitor LG Ultrawide  Eletrodomésticos  4614.41
# 2         Loja Física            Chromecast Google       Informática   514.37
# 3         Loja Física   Máquina de Barbear Philips       Informática  3216.11
# 4         Loja Física         Notebook Acer Aspire       Informática  3329.32
# ...               ...                          ...               ...      ...
# 23995     Loja Física         Monitor LG Ultrawide  Eletrodomésticos  4614.41
# 23996          Online    Tablet Samsung Galaxy Tab            Móveis  3150.89
# 23997          Online          Monitor Samsung 24"       Eletrônicos  2946.66
# 23998     Loja Física                Luminária LED       Eletrônicos  3278.33
# 23999          Online             Cooktop Brastemp       Eletrônicos  4648.09
#
#           marca
# 0       Mondial
# 1            LG
# 2        Google
# 3       Philips
# 4          Acer
# ...         ...
# 23995        LG
# 23996   Samsung
# 23997   Samsung
# 23998  Genérico
# 23999  Brastemp
#
# [24000 rows x 17 columns]

# %%
tabela_final.groupby("sexo")["valor_total"].sum().reset_index().sort_values(by="valor_total", ascending=False)
# Out:
#   sexo   valor_total
# 1    M  1.523881e+09
# 0    F  1.290266e+09

# %%
tabela_final.loc[tabela_final['sexo'] == 'F']
# Out:
#        id_venda  id_cliente  id_produto        data  quantidade        canal  \
# 0             1         350          45  2022-09-23           4       Online
# 3             4         494          47  2024-05-10           4  Loja Física
# 4             5         523          79  2023-10-15           4  Loja Física
# 5             6          98          30  2022-10-11           1  Loja Física
# 9            10         570          34  2023-05-12           4       Online
# ...         ...         ...         ...         ...         ...          ...
# 23987     23187          44          91  2025-07-05           2  Loja Física
# 23988     23188         767          93  2025-07-22           4       Online
# 23991     23191         208          39  2025-07-29           3       Online
# 23996     23196         225          90  2024-10-14           2  Loja Física
# 23997     23197         974          15  2024-12-29           4  Loja Física
#
#        valor_total                       nome  idade sexo          cidade  \
# 0          5795.64          Davi Luiz Peixoto     39    F  Rio de Janeiro
# 3         12864.44          Kevin Casa Grande     51    F        Curitiba
# 4         13317.28             Asafe Mendonça     29    F    Porto Alegre
# 5          3282.59       Srta. Maya Aparecida     58    F    Porto Alegre
# 9          1445.64             Beatriz Santos     57    F       São Paulo
# ...            ...                        ...    ...  ...             ...
# 23987   1083252.00               Ian Cassiano     24    F  Rio de Janeiro
# 23988   1873526.00  Gustavo Henrique Mendonça     55    F    Porto Alegre
# 23991   1500485.00             Mateus Peixoto     59    F       São Paulo
# 23996    653663.00           Ana Clara Cirino     54    F  Belo Horizonte
# 23997   1256521.00             Yasmin Pimenta     66    F       São Paulo
#
#       estado canal_aquisicao                 nome_produto         categoria  \
# 0         MG     Loja Física  Fritadeira Airfryer Mondial            Móveis
# 3         PR     Loja Física   Máquina de Barbear Philips       Informática
# 4         SP     Loja Física         Notebook Acer Aspire       Informática
# 5         SP          Online               Relógio Garmin       Informática
# 9         PR          Online            Estabilizador APC  Eletrodomésticos
# ...      ...             ...                          ...               ...
# 23987     PR          Online              Monitor AOC 27"  Eletrodomésticos
# 23988     RJ     Loja Física     Mouse Logitech MX Master       Informática
# 23991     PR     Loja Física    Controle Remoto Universal       Informática
# 23996     RJ          Online    Tablet Samsung Galaxy Tab            Móveis
# 23997     PR          Online          Monitor Samsung 24"       Eletrônicos
#
#          preco     marca
# 0      1448.91   Mondial
# 3      3216.11   Philips
# 4      3329.32      Acer
# 5      3282.59    Garmin
# 9       361.41       APC
# ...        ...       ...
# 23987  4869.57       AOC
# 23988  4252.20  Logitech
# 23991  4714.29     Inova
# 23996  3150.89   Samsung
# 23997  2946.66   Samsung
#
# [11287 rows x 17 columns]

# %%
tabela_final.loc[tabela_final['sexo'] == 'M']
# Out:
#        id_venda  id_cliente  id_produto        data  quantidade        canal  \
# 1             2         925          68  2024-02-09           1  Loja Física
# 2             3         915          75  2022-09-11           4       Online
# 6             7         946          24  2024-02-24           4  Loja Física
# 7             8          71          66  2024-03-07           2       Online
# 8             9         364          43  2023-06-18           2  Loja Física
# ...         ...         ...         ...         ...         ...          ...
# 23993     23193         863           2  2025-06-07           1  Loja Física
# 23994     23194         617          96  2025-01-26           2       Online
# 23995     23195          99          68  2024-11-06           2       Online
# 23998     23198         269          44  2025-06-13           3  Loja Física
# 23999     23199          54          23  2024-12-02           2       Online
#
#        valor_total                        nome  idade sexo          cidade  \
# 1          4614.41                Murilo Cunha     28    M    Porto Alegre
# 2          2057.48                Jade Freitas     30    M    Porto Alegre
# 6         18611.12            Bernardo Costela     39    M        Curitiba
# 7          5811.56  Dr. Gael Henrique da Cunha     23    M  Rio de Janeiro
# 8         70319.40               Leandro Brito     50    M  Belo Horizonte
# ...            ...                         ...    ...  ...             ...
# 23993    342823.00                Raquel Pires     67    M  Rio de Janeiro
# 23994     85676.00            Aylla Montenegro     41    M  Belo Horizonte
# 23995    922882.00           Ana Lívia Pereira     46    M       São Paulo
# 23998    983499.00               Ester Azevedo     37    M  Belo Horizonte
# 23999    929618.00           Davi Lucas Araújo     43    M  Belo Horizonte
#
#       estado canal_aquisicao                   nome_produto         categoria  \
# 1         PR          Online           Monitor LG Ultrawide  Eletrodomésticos
# 2         RJ     Loja Física              Chromecast Google       Informática
# 6         PR     Loja Física          Forno Elétrico Philco            Móveis
# 7         PR     Loja Física           Smartphone iPhone 13       Eletrônicos
# 8         RS     Loja Física              Extensão Elétrica  Eletrodomésticos
# ...      ...             ...                            ...               ...
# 23993     MG          Online  Smartphone Samsung Galaxy S21  Eletrodomésticos
# 23994     RS     Loja Física              Smartwatch Huawei       Informática
# 23995     RS     Loja Física           Monitor LG Ultrawide  Eletrodomésticos
# 23998     PR     Loja Física                  Luminária LED       Eletrônicos
# 23999     MG          Online               Cooktop Brastemp       Eletrônicos
#
#          preco      marca
# 1      4614.41         LG
# 2       514.37     Google
# 6      4652.78     Philco
# 7      2905.78      Apple
# 8      3515.97  I Clamper
# ...        ...        ...
# 23993  3306.28    Samsung
# 23994   428.38     Huawei
# 23995  4614.41         LG
# 23998  3278.33   Genérico
# 23999  4648.09   Brastemp
#
# [12713 rows x 17 columns]

# %%
'''q1 = np.percentile(tabela_final, 25)
q2 = np.percentile(tabela_final, 50)
q3 = np.percentile(tabela_final, 75)
mediana = np.median(tabela_final) # median = mediana

print(f'Primeiro quartil (Q1): {q1}')
print(f'Primeiro quartil (Q2): {q2}')
print(f'Primeiro quartil (Q3): {q3}')
print(f'Mediana {mediana}')'''
# Out:
# "q1 = np.percentile(tabela_final, 25)\nq2 = np.percentile(tabela_final, 50)\nq3 = np.percentile(tabela_final, 75)\nmediana = np.median(tabela_final) # median = mediana\n\nprint(f'Primeiro quartil (Q1): {q1}')\nprint(f'Primeiro quartil (Q2): {q2}')\nprint(f'Primeiro quartil (Q3): {q3}')\nprint(f'Mediana {mediana}')"

# %%
tabela_produtos = tabela_final[['nome_produto', 'preco']].drop_duplicates().reset_index(drop=True)
tabela_produtos = tabela_produtos.dropna()
tabela_produtos
# Out:
#                      nome_produto    preco
# 0     Fritadeira Airfryer Mondial  1448.91
# 1            Monitor LG Ultrawide  4614.41
# 2               Chromecast Google   514.37
# 3      Máquina de Barbear Philips  3216.11
# 4            Notebook Acer Aspire  3329.32
# ..                            ...      ...
# 94  Smartphone Samsung Galaxy S21  3306.28
# 95                Ventilador Arno  3024.57
# 96           Mouse Gamer Redragon  3004.92
# 97                Echo Dot Amazon   255.54
# 98                  Controle Xbox  3917.60
#
# [99 rows x 2 columns]

# %%
tabela_produtos_array = np.array(tabela_produtos['preco'])

q1 = np.percentile(tabela_produtos_array, 25)
q2 = np.percentile(tabela_produtos_array, 50)
q3 = np.percentile(tabela_produtos_array, 75)
mediana = np.median(tabela_produtos_array) # median = median
media = np.mean(tabela_produtos_array) # mean = média

print(f'Primeiro quartil (Q1): {q1}')
print(f'Primeiro quartil (Q2): {q2}')
print(f'Primeiro quartil (Q3): {q3}')
print(f'Mediana {mediana}')
print(f'Média {media}')
# Out:
# Primeiro quartil (Q1): 1759.105
# Primeiro quartil (Q2): 3087.52
# Primeiro quartil (Q3): 4033.355
# Mediana 3087.52
# Média 2850.3936363636362

# %%
contagem = tabela_final['nome_produto'].value_counts().reset_index()
contagem
# Out:
#                      nome_produto  count
# 0   Geladeira Brastemp Frost Free    276
# 1          Pen Drive Sandisk 64GB    272
# 2               Kindle Paperwhite    272
# 3      Aspirador de Pó Electrolux    272
# 4                Teclado Logitech    271
# ..                            ...    ...
# 95           Mouse Gamer Redragon    213
# 96           Volante Logitech G29    209
# 97              Smartwatch Xiaomi    204
# 98   Gabinete Gamer Cooler Master    201
# 99                         Mouse      44
#
# [100 rows x 2 columns]

# %%
count_array = np.array(contagem['count'])

q1 = np.percentile(count_array, 25)
q2 = np.percentile(count_array, 50)
q3 = np.percentile(count_array, 75)
mediana = np.median(count_array) 
media = np.mean(count_array) 
distancia =  (media - mediana) / mediana
iqr = q3 - q1
limite_inferior = q1 - (1.5 * iqr)

print(f'Primeiro quartil (Q1): {q1}')
print(f'Primeiro quartil (Q2): {q2}')
print(f'Primeiro quartil (Q3): {q3}')
print(f'Mediana {mediana}')
print(f'Média {media}')
print(f'Limite Inferior: {limite_inferior}')
print(f'Distância: {distancia}')
# Out:
# Primeiro quartil (Q1): 232.0
# Primeiro quartil (Q2): 240.5
# Primeiro quartil (Q3): 253.5
# Mediana 240.5
# Média 240.0
# Limite Inferior: 199.75
# Distância: -0.002079002079002079

# %%
count_outliers = contagem[contagem['count'] < q1]
count_outliers
# Out:
#                     nome_produto  count
# 76          Fire TV Stick Amazon    231
# 77        Câmera Canon EOS Rebel    230
# 78          Smartphone iPhone 13    230
# 79            Fone de Ouvido JBL    229
# 80                    Cabo USB-C    229
# 81               Filtro de Linha    228
# 82         Impressora HP Deskjet    227
# 83     Controle Remoto Universal    226
# 84        Micro-ondas Electrolux    225
# 85                 Controle Xbox    225
# 86               Echo Dot Amazon    225
# 87       Notebook Lenovo Ideapad    224
# 88                Placa-mãe ASUS    223
# 89   Fritadeira Airfryer Mondial    222
# 90     Tablet Samsung Galaxy Tab    222
# 91          Máquina de Lavar 8kg    222
# 92             Extensão Elétrica    221
# 93             Estabilizador APC    215
# 94       Cadeira Gamer ThunderX3    214
# 95          Mouse Gamer Redragon    213
# 96          Volante Logitech G29    209
# 97             Smartwatch Xiaomi    204
# 98  Gabinete Gamer Cooler Master    201
# 99                        Mouse      44

# %%
count_outliers.to_csv('produtos_outliers.csv', index=False)

# %%
tabela_final.to_csv('tabela_final.csv', index=False)

# %%
tabela_final
# Out:
#        id_venda  id_cliente  id_produto        data  quantidade        canal  \
# 0             1         350          45  2022-09-23           4       Online
# 1             2         925          68  2024-02-09           1  Loja Física
# 2             3         915          75  2022-09-11           4       Online
# 3             4         494          47  2024-05-10           4  Loja Física
# 4             5         523          79  2023-10-15           4  Loja Física
# ...         ...         ...         ...         ...         ...          ...
# 23995     23195          99          68  2024-11-06           2       Online
# 23996     23196         225          90  2024-10-14           2  Loja Física
# 23997     23197         974          15  2024-12-29           4  Loja Física
# 23998     23198         269          44  2025-06-13           3  Loja Física
# 23999     23199          54          23  2024-12-02           2       Online
#
#        valor_total               nome  idade sexo          cidade estado  \
# 0          5795.64  Davi Luiz Peixoto     39    F  Rio de Janeiro     MG
# 1          4614.41       Murilo Cunha     28    M    Porto Alegre     PR
# 2          2057.48       Jade Freitas     30    M    Porto Alegre     RJ
# 3         12864.44  Kevin Casa Grande     51    F        Curitiba     PR
# 4         13317.28     Asafe Mendonça     29    F    Porto Alegre     SP
# ...            ...                ...    ...  ...             ...    ...
# 23995    922882.00  Ana Lívia Pereira     46    M       São Paulo     RS
# 23996    653663.00   Ana Clara Cirino     54    F  Belo Horizonte     RJ
# 23997   1256521.00     Yasmin Pimenta     66    F       São Paulo     PR
# 23998    983499.00      Ester Azevedo     37    M  Belo Horizonte     PR
# 23999    929618.00  Davi Lucas Araújo     43    M  Belo Horizonte     MG
#
#       canal_aquisicao                 nome_produto         categoria    preco  \
# 0         Loja Física  Fritadeira Airfryer Mondial            Móveis  1448.91
# 1              Online         Monitor LG Ultrawide  Eletrodomésticos  4614.41
# 2         Loja Física            Chromecast Google       Informática   514.37
# 3         Loja Física   Máquina de Barbear Philips       Informática  3216.11
# 4         Loja Física         Notebook Acer Aspire       Informática  3329.32
# ...               ...                          ...               ...      ...
# 23995     Loja Física         Monitor LG Ultrawide  Eletrodomésticos  4614.41
# 23996          Online    Tablet Samsung Galaxy Tab            Móveis  3150.89
# 23997          Online          Monitor Samsung 24"       Eletrônicos  2946.66
# 23998     Loja Física                Luminária LED       Eletrônicos  3278.33
# 23999          Online             Cooktop Brastemp       Eletrônicos  4648.09
#
#           marca
# 0       Mondial
# 1            LG
# 2        Google
# 3       Philips
# 4          Acer
# ...         ...
# 23995        LG
# 23996   Samsung
# 23997   Samsung
# 23998  Genérico
# 23999  Brastemp
#
# [24000 rows x 17 columns]
